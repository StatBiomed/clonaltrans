# %% [markdown]
# # Day 3 GFP+

# %%
import pandas as pd
import numpy as np
import pickle
import sklearn
import platform
import scanpy as sc
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
color_map = LinearSegmentedColormap.from_list('ss2_to_10x', ['lightgrey', 'red', 'darkred'])
import gzip

# %% [markdown]
# # Cutadapt 1

# %% [markdown]
# ~/.local/bin/cutadapt -g TTGCTAGGAGAGACCATATG...ATGTCTGGATCCGATATCGC -o pre_barcode_D3.fq.gz -p pre-cbc_D3.fq.gz SLX-22548.SITTA1.HJWKYDSX5.s_3.r_2.fq.gz SLX-22548.SITTA1.HJWKYDSX5.s_3.r_1.fq.gz --discard-untrimmed --pair-filter=both

# %% [markdown]
# === Summary ===
#
# Total read pairs processed:          8,538,850
#   Read 1 with adapter:               8,071,756 (94.5%)
#   Read 2 with adapter:                       0 (0.0%)
# Pairs written (passing filters):     8,071,756 (94.5%)
#
# Total basepairs processed: 1,007,584,300 bp
#   Read 1:   768,496,500 bp
#   Read 2:   239,087,800 bp
# Total written (filtered):    548,369,469 bp (54.4%)
#   Read 1:   322,360,301 bp
#   Read 2:   226,009,168 bp
#
# === First read: Adapter 3 ===
#
# Sequence: TTGCTAGGAGAGACCATATG...ATGTCTGGATCCGATATCGC; Type: linked; Length: 20+20; 5' trimmed: 8071756 times; 3' trimmed: 8071756 times
#
#
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 17	2	0.0	1	2
# 18	8	0.0	1	4 4
# 19	10	0.0	1	9 1
# 20	98	0.0	2	15 19 64
# 21	902	0.0	2	55 213 634
# 22	13492	0.0	2	854 4109 8529
# 23	181149	0.0	2	44505 132020 4624
# 24	7852259	0.0	2	7571777 246118 34364
# 25	21602	0.0	2	5890 14273 1439
# 26	2207	0.0	2	18 9 2180
# 27	7	0.0	2	5 0 2
# 28	7	0.0	2	5 1 1
# 29	6	0.0	2	5 1
# 30	3	0.0	2	1 2
# 32	2	0.0	2	2
# 36	1	0.0	2	1
# 46	1	0.0	2	1
#
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 3	5575	133419.5	0	5575
# 4	250	33354.9	0	250
# 5	6	8338.7	0	6
# 6	1	2084.7	0	1
# 13	10	0.1	1	9 1
# 14	11	0.0	1	11
# 15	5	0.0	1	5
# 18	3	0.0	1	3
# 19	5	0.0	1	5
# 20	16	0.0	2	15 1
# 21	15	0.0	2	14 1
# 22	37	0.0	2	36 0 1
# 23	110	0.0	2	100 7 3
# 24	887	0.0	2	815 57 15
# 25	50453	0.0	2	47046 2484 923
# 26	7448189	0.0	2	7031704 330814 85671
# 27	412654	0.0	2	382907 22990 6757
# 28	110417	0.0	2	74411 32349 3657
# 29	8488	0.0	2	7292 1020 176
# 30	2206	0.0	2	2059 132 15
# 31	3401	0.0	2	996 2311 94
# 32	23616	0.0	2	22483 921 212
# 33	3499	0.0	2	3262 194 43
# 34	119	0.0	2	110 7 2
# 35	36	0.0	2	34 2
# 37	11	0.0	2	11
# 38	34	0.0	2	25 7 2
# 39	1	0.0	2	1
# 40	51	0.0	2	30 13 8
# 41	23	0.0	2	23
# 42	1376	0.0	2	1330 36 10
# 43	58	0.0	2	54 3 1
# 44	2	0.0	2	2
# 47	4	0.0	2	4
# 48	17	0.0	2	16 0 1
# 49	20	0.0	2	9 1 10
# 50	18	0.0	2	7 0 11
# 51	13	0.0	2	13
# 52	24	0.0	2	21 2 1
# 53	10	0.0	2	10
# 54	5	0.0	2	4 1
# 55	15	0.0	2	15
# 56	17	0.0	2	17
# 57	6	0.0	2	6
# 58	4	0.0	2	3 1
# 59	18	0.0	2	18
# 65	6	0.0	2	0 0 6
# 66	13	0.0	2	0 4 9
# 67	1	0.0	2	0 1

# %% [markdown]
# # Cutadapt 2

# %% [markdown]
# ~/.local/bin/cutadapt -g "NNNNTGNNNNCANNNNACNNNNGANNNNGTNNNNAGNNNN;min_overlap=36" -o larrybarcode_D3.fastq -p cbcumi_D3.fastq pre_barcode_D3.fq.gz pre-cbc_D3.fq.gz --discard-untrimmed --action=retain --pair-filter=both

# %%
=== Summary ===

Total read pairs processed:          8,071,756
  Read 1 with adapter:               7,927,755 (98.2%)
  Read 2 with adapter:                       0 (0.0%)
Pairs written (passing filters):     7,927,755 (98.2%)

Total basepairs processed:   548,369,469 bp
  Read 1:   322,360,301 bp
  Read 2:   226,009,168 bp
Total written (filtered):    538,941,311 bp (98.3%)
  Read 1:   316,964,171 bp
  Read 2:   221,977,140 bp

=== First read: Adapter 1 ===

Sequence: NNNNTGNNNNCANNNNACNNNNGANNNNGTNNNNAGNNNN; Type: regular 5'; Length: 40; Trimmed: 7927755 times

No. of allowed errors:
1-9 bp: 0; 10-12 bp: 1

Overview of removed sequences
length	count	expect	max.err	error counts
36	9	0.0	3	6 3
37	2834	0.0	3	2723 111
38	19331	0.0	3	8249 11082
39	246479	0.0	3	32967 213512
40	7632333	0.0	4	7401026 231307
41	26667	0.0	4	3108 23559
42	56	0.0	4	5 51
43	23	0.0	4	5 18
44	4	0.0	4	1 3
46	5	0.0	4	5
53	11	0.0	4	11
60	1	0.0	4	1
63	2	0.0	4	2

# %% [markdown]
# # fastq to txt files

# %% [markdown]
# sed -n '2~4p' larrybarcode_D3.fastq > larrybarcode_file_D3.txt

# %% [markdown]
# sed -n '2~4p' cbcumi_D3.fastq > 10xcbcUMI_file_D3.txt

# %% [markdown]
# # Filter LARRY Barcodes with length 40; and 10x CBC UMI with length 28

# %%
larry_unfiltered=np.loadtxt("larrybarcode_file_D3.txt", dtype=str)

# %%
r1=np.loadtxt("10xcbcUMI_file_D3.txt", dtype=str)

# %%
length_checker = np.vectorize(len)
larry_barcode_len = length_checker(larry_unfiltered)

# %%
mask_1 = np.where(larry_barcode_len == 40)

# %%
larry_filtered = larry_unfiltered[mask_1]

# %%
r1_filtered = r1[mask_1]

# %%
r1_len = length_checker(r1_filtered)

# %%
mask_2 = np.where(r1_len == 28)

# %%
r1_filtered = r1_filtered[mask_2]

# %%
larry_filtered = larry_filtered[mask_2]

# %% [markdown]
# # Extracting 10x Barcode and UMI

# %%
cbc = []
umi = []
for i in r1_filtered:
    x = i[:16]
    y = i[16:]
    cbc.append(x)
    umi.append(y)

# %%
cbc = np.array(cbc)

# %%
umi = np.array(umi)

# %%
np.size(cbc)
# Out:
# 7622882

# %%
np.size(umi)
# Out:
# 7622882

# %% [markdown]
# # Subset Larry, CBC and UMI by Valid 10x Barcodes

# %%
valid_cbc = np.loadtxt("/home/sc992/rds/rds-bg200-hphi-gottgens/users/sc992/LARRY_Barcode/SLX22548/SITTG7/outs/filtered_feature_bc_matrix/barcodes.tsv", dtype=str)

# %%
#valid_cbc.tolist()

# %%
x = [str.split(cbc, '-')[0] for cbc in valid_cbc]

# %%
valid_cbc = x

# %%
#valid_cbc

# %%
np.size(valid_cbc)
# Out:
# 3426

# %%
mask_3 = np.where(np.in1d(cbc,valid_cbc))

# %%
larry_filtered = larry_filtered[mask_3]

# %%
cbc_filtered = cbc[mask_3]

# %%
y = ['SITTG7'+cbc for cbc in cbc_filtered]

# %%
#y

# %%
cbc_filtered = y

# %%
umi_filtered = umi[mask_3]

# %%
np.savetxt('larry_D3.txt', larry_filtered, fmt='%s')

# %%
np.savetxt("umi_D3.txt",umi_filtered, fmt='%s')

# %%
np.savetxt("cbc_D3.txt",cbc_filtered, fmt='%s')

# %% [markdown]
# # Generate fastq file with correct configuration

# %%
out = gzip.open('LARRY_sorted_and_filtered_barcodes_D3.fastq.gz','wb')

# %%
for i in range(len(larry_filtered)):
    lib = 'SITTG7'
    gfp_bc = larry_filtered[i]
    umi = umi_filtered[i]
    cell_bc = cbc_filtered[i]
    tag = '>'+lib+','+cell_bc+','+umi
    out.write((tag+'\n').encode('utf-8'))
    out.write((gfp_bc+'\n').encode('utf-8'))
    out.write('\n'.encode('utf-8'))

# %%
out.close()

# %% [markdown]
# # Generate a txt file for valid cbc and library

# %%
#valid_cbc

# %%
z = ['SITTG7'+cbc for cbc in valid_cbc]

# %%
#z

# %%
np.savetxt('cell_bcs_flat_D3.txt', z, fmt='%s')

# %%
lib = []

# %%
for i in z: 
    lib.append('SITTG7')

# %%
np.size(lib)
# Out:
# 3426

# %%
np.savetxt('samp_id_flat_D3.txt', lib, fmt='%s')
