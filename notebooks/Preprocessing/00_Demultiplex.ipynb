# %% [markdown]
# # Demultiplex Files

# %% [markdown]
# SITTA3, SITTA6 and SITTA7 have ended up in the lost reads. This is because the i5 primers is in the opposite direction to what appears in the sequencing

# %%
pwd
# Out:
# '/rds/project/rds-SDzz0CATGms/users/sc992/LARRY_Barcode/SLX22548'

# %%
/rds/project/rds-SDzz0CATGms/users/sc992/demultiplex/bbmap/demuxbyname.sh \
    prefixmode=f \
    in=./SLX-22548.HJWKYDSX5.s_3.r_1.lostreads.fq.gz \
    in2=./SLX-22548.HJWKYDSX5.s_3.r_2.lostreads.fq.gz \
    out=%_R1_001.fastq.gz \
    out2=%_R2_001.fastq.gz \
    names=CACTACGAAA+TTAGACTGAT,TAACGCGTGA+CCCTAACTTC,TCCCAAGGGT+TACTACCTTT

# %%
# Rename Files post demultiplex

# %%
mv CACTACGAAA+TTAGACTGAT_R1_001.fastq.gz SITTA3_r1.fq.gz

# %%
mv CACTACGAAA+TTAGACTGAT_R2_001.fastq.gz SITTA3_r2.fq.gz

# %%
mv TAACGCGTGA+CCCTAACTTC_R1_001.fastq.gz SITTA6_r1.fq.gz

# %%
mv TAACGCGTGA+CCCTAACTTC_R2_001.fastq.gz SITTA6_r2.fq.gz

# %%
mv TCCCAAGGGT+TACTACCTTT_R1_001.fastq.gz SITTA7_r1.fq.gz

# %%
mv TCCCAAGGGT+TACTACCTTT_R2_001.fastq.gz SITTA7_r2.fq.gz
